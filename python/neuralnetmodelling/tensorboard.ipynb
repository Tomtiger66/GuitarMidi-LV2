# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6007 (pid 49846), started 0:00:01 ago. (Use '!kill 49846' to kill it.)
#       <iframe id="tensorboard-frame-95d90831c010fc6e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-95d90831c010fc6e");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
