# %%
from scipy import io
import numpy as np
dataslices_output='data_slices/output'
batch_size=1
num_harmonics=4 
audio_dir='../../assets/trainingdata/chords/'
sampleRate,audio=io.wavfile.read(audio_dir+'session_original.wav')
audio=audio.astype(np.float32)
_,audio_hi=io.wavfile.read(audio_dir+'session_eq high.wav')
audio_hi=audio_hi.astype(np.float32)
_,audio_mid=io.wavfile.read(audio_dir+'session_eq mid.wav')
audio_mid=audio_mid.astype(np.float32)
_,audio_dist=io.wavfile.read(audio_dir+'session_tape dist.wav')
audio_dist=audio_dist.astype(np.float32)
print(len(audio))
use_augmentations=True
# Out:
# 12576000

# %%
import numpy as np
import seaborn as sns
from fretboard import FretBoard
    
    
filter =FretBoard(20,sampleRate)
numfilters=filter.get_num_filters()
filterbank_out=np.zeros((numfilters,len(audio)),dtype=np.float32)
filter.process(audio,filterbank_out)


if use_augmentations:
    print('Processing Augmentations')
    filter_hi =FretBoard(20,sampleRate)
    filter_mid =FretBoard(20,sampleRate)
    filter_dist =FretBoard(20,sampleRate)
    print('num filters:'+str(numfilters)+' audio samples '+str(len(audio)))
    
    
    
    filterbank_out_hi=np.zeros((numfilters,len(audio)),dtype=np.float32)
    filterbank_out_mid=np.zeros((numfilters,len(audio)),dtype=np.float32)
    filterbank_out_dist=np.zeros((numfilters,len(audio)),dtype=np.float32)
    
    
    
    
    filter_hi.process(audio_hi,filterbank_out_hi)
    filter_mid.process(audio_mid,filterbank_out_mid)
    filter_dist.process(audio_dist,filterbank_out_dist)
else: 
    print('NOT Processing augmentations')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 9
#       7 numfilters=filter.get_num_filters()
#       8 filterbank_out=np.zeros((numfilters,len(audio)),dtype=np.float32)
# ----> 9 filter.process(audio,filterbank_out)
#      12 if use_augmentations:
#      13     print('Processing Augmentations')
#
# File ~/workspace/src/GuitarMidi-LV2/python/neuralnetmodelling/fretboard.py:93, in FretBoard.process(self, input_audio, filterbank_out)
#      89 def process(self, input_audio, filterbank_out: np.array):
#      91     for h in self.frets:
#      92         # filterbank_out.append(h.process(input_audio,filterbank_out))
# ---> 93         res=h.process(input_audio,filterbank_out)
#
# File ~/workspace/src/GuitarMidi-LV2/python/neuralnetmodelling/fretboard.py:62, in Fret.process(self, input_audio, filterbank_out)
#      58 def process(self, input_audio, filterbank_out: np.array):
#      60     for h in self.strings:
#      61         #filterbank_out.append(h.process(input_audio,filterbank_out))
# ---> 62         h.process(input_audio,filterbank_out)
#
# File ~/workspace/src/GuitarMidi-LV2/python/neuralnetmodelling/fretboard.py:34, in HarmonicGroup.process(self, input_audio, filterbank_out)
#      31 res=filterbank_out
#      32 for h in self.harmonics:
#      33     #filterbank_out.append(h.process(input_audio))
# ---> 34     h.process(input_audio,filterbank_out)
#      36 return res
#
# File ~/workspace/src/GuitarMidi-LV2/python/neuralnetmodelling/fretboard.py:19, in Filter.process(self, input_audio, filterbank_out)
#      18 def process(self,input_audio,filterbank_out: np.array):
# ---> 19     filterbank_out[self.id]=np.abs(signal.filtfilt(self.b, self.a, input_audio))
#
# File ~/miniconda3/envs/gpu/lib/python3.13/site-packages/scipy/signal/_signaltools.py:4838, in filtfilt(b, a, x, axis, padtype, padlen, method, irlen)
#    4835 x0 = axis_slice(ext, stop=1, axis=axis)
#    4837 # Forward filter.
# -> 4838 (y, zf) = lfilter(b, a, ext, axis=axis, zi=zi * x0)
#    4840 # Backward filter.
#    4841 # Create y0 so zi*y0 broadcasts appropriately.
#    4842 y0 = axis_slice(y, start=-1, axis=axis)
#
# File ~/miniconda3/envs/gpu/lib/python3.13/site-packages/scipy/signal/_signaltools.py:2306, in lfilter(b, a, x, axis, zi)
#    2304     return xp.asarray(result)
#    2305 else:
# -> 2306     out, zf = _sigtools._linear_filter(b, a, x, axis, zi)
#    2307     return xp.asarray(out), xp.asarray(zf)
#
# KeyboardInterrupt:

# %%
from common import frame_size



nn_input=reshape_to_nn_input(filterbank_out)
filterbank_out=None
if use_augmentations:
    nn_input_all=np.concatenate((nn_input,nn_input,nn_input,nn_input),axis=0)
    nsamples=nn_input.shape[0];
    nn_input_all[range(nsamples,2*nsamples)]=reshape_to_nn_input(filterbank_out_hi)
    filterbank_out_hi=None
    
    nn_input_all[range(2*nsamples,3*nsamples)]=reshape_to_nn_input(filterbank_out_mid)
    filterbank_out_mid=None
    
    nn_input_all[range(3*nsamples,4*nsamples)]=reshape_to_nn_input(filterbank_out_dist)
    filterbank_out_dist=None
    
    
    print(nn_input_all.shape)
# Out:
# reshape data by a factor of 256...
# (312, 12576000)
# (312, 49125, 256)
# (312, 49125)
# Reshaped the input data to
# (49125, 312)

# %%
from common import save_data_slices
output_dir_input = 'data_slices/input'
if use_augmentations:
    save_data_slices(output_dir_input,nn_input_all,batch_size)
else:
    save_data_slices(output_dir_input,nn_input,batch_size)
# Out:
# Saving 49125 samples to disk
# Serialization complete. 49125 Files saved in 'data_slices/input'.

# %%
nn_input_all=None
nn_input=None
